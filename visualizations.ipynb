# %%
print("ciao")
# Out:
# ciao

# %%
from utils import interactive_tsne_with_images, interactive_tsne_over_checkpoints

# %%
chart = interactive_tsne_over_checkpoints(
    ckpt_dir=r"C:\Users\nicco\OneDrive\Documenti\JurassicClass\models\cross_validation\classifeir_only\EfficentRex",
    ckpt_files=[r"fold_0\best-epoch=39-val_loss=0.5355-val_acc=0.8269.ckpt",
                r"fold_1\best-epoch=38-val_loss=0.6836-val_acc=0.8104.ckpt",
                r"fold_2\best-epoch=39-val_loss=0.6525-val_acc=0.8072.ckpt",
                r"fold_3\best-epoch=17-val_loss=0.7068-val_acc=0.7851.ckpt",
                r"fold_4\best-epoch=30-val_loss=0.7101-val_acc=0.7824.ckpt"],
    _model = "EfficentRex",
    data_dir = "dataset/dataset",
    point_size = 25,
    save_html = "images/prova_tsne.html"
)
# Out:
# Checkpoint: fold_0\best-epoch=39-val_loss=0.5355-val_acc=0.8269.ckpt
# ...

# %%
chart
# Out:
# alt.LayerChart(...)
